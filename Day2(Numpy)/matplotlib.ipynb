# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.random.randint(1,50,20)
y=np.random.randint(-10,50,20)

# %%
x,y
# Out:
# (array([26, 43,  9, 41, 46, 33, 12, 48, 14, 34, 42,  1,  7, 15, 25, 38,  3,
#          6, 45, 26]),
#  array([ 5, 13, 27,  4, 19, 39, -1, -3, 45, -2, 25, 48, 38, 27,  5,  5, 20,
#         21,  0, 19]))

# %%
x
# Out:
# array([26, 43,  9, 41, 46, 33, 12, 48, 14, 34, 42,  1,  7, 15, 25, 38,  3,
#         6, 45, 26])

# %%
plt.figure(figsize=(5,2))
plt.xlabel("x axis")
plt.ylabel("Y axis")
plt.title("Random graph")
plt.plot(x,y)

# %%
x1=np.random.randint(1,100,20)
x2=np.random.randint(-100,0,20)
plt.figure(figsize=(5,2))
plt.title("Random graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x,y)

# %%
x1=np.random.randint(1,100,20)
x2=np.random.randint(-100,0,20)
plt.figure(figsize=(5,2))
plt.title("Random graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.scatter(x,y)

# %%
x1=np.random.randint(1,100,20)
x2=np.random.randint(-100,0,20)
colour=np.random.randint(10,100,20)
size=np.random.randint(1,200,20)
plt.figure(figsize=(5,2))
plt.title("Random graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.scatter(x,y,c=colour,s=size)

# %%
x1=np.random.randint(1,100,5)
x2=np.random.randint(-100,0,5)
plt.figure(figsize=(5,5))
plt.title("Random graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
x1=np.random.randint(1,100,5)
x2=np.random.randint(-100,0,5)
plt.figure(figsize=(5,5))
plt.title("Random graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.barh(x,y)
# Out:
# <BarContainer object of 20 artists>

# %%
x1=np.random.randint(1,100,5)
x2=np.random.randint(-100,0,5)
plt.figure(figsize=(5,5))
plt.title("Random graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.hist(x)
# Out:
# (array([2., 3., 3., 0., 0., 3., 1., 2., 3., 3.]),
#  array([ 1. ,  5.7, 10.4, 15.1, 19.8, 24.5, 29.2, 33.9, 38.6, 43.3, 48. ]),
#  <BarContainer object of 10 artists>)

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)

fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z)

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)

fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z)
