# %% [markdown]
# ### Linear Regression, Ridge Regression, Lasso Regression , Elastic Net on Algeria Forest Fire data set

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cleaned_dataset.csv')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df.drop(['day','month','year'],inplace=True,axis=1)

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 0     not fire          0
# 1     not fire          0
# 2     not fire          0
# 3     not fire          0
# 4     not fire          0
# ...

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int64
#  1   RH           243 non-null    int64
#  2   Ws           243 non-null    int64
#  3   Rain         243 non-null    float64
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  Classes      243 non-null    int64
#  11  Region       243 non-null    int64
# dtypes: float64(7), int64(5)
# memory usage: 22.9 KB

# %% [markdown]
# ### Independent Variable and Dependent Variable

# %%
y=df['FWI']
X=df.drop('FWI',axis=1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df.describe()
# Out:
#        Temperature          RH          Ws        Rain        FFMC  \
# count   243.000000  243.000000  243.000000  243.000000  243.000000
# mean     32.152263   62.041152   15.493827    0.762963   77.842387
# std       3.628039   14.828160    2.811385    2.003207   14.349641
# min      22.000000   21.000000    6.000000    0.000000   28.600000
# 25%      30.000000   52.500000   14.000000    0.000000   71.850000
# 50%      32.000000   63.000000   15.000000    0.000000   83.300000
# 75%      35.000000   73.500000   17.000000    0.500000   88.300000
# max      42.000000   90.000000   29.000000   16.800000   96.000000
#
#               DMC          DC         ISI         BUI         FWI     Classes  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean    14.680658   49.430864    4.742387   16.690535    7.035391    0.563786
# std     12.393040   47.665606    4.154234   14.228421    7.440568    0.496938
# ...

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Train Test Split to the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# Region          0.269555 -0.402682 -0.181160 -0.040013  0.222241  0.192089
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
sns.heatmap(X.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Program to drop highly related features

# %%
def correlation(dataset,threshold):
    corr_name=set()
    corr_matrix=dataset.corr()
    for i in range (len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                col_name=corr_matrix.columns[i]
                corr_name.add(col_name)
    return corr_name

# %%
corr_name=correlation(X_train,0.80)

# %%
corr_name
# Out:
# {'BUI', 'DC'}

# %%
X_train.drop(corr_name,axis=True,inplace=True)
X_test.drop(corr_name,axis=True,inplace=True)

# %% [markdown]
# ### Standard Scalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler=StandardScaler();

# %%
X_train_scaled=Scaler.fit_transform(X_train)
X_test=Scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-1.12656349,  1.2199876 , -0.22762867, ..., -0.11433646,
#          0.90566259,  0.9877296 ],
#        [ 0.52256258,  0.1473255 , -0.98795537, ...,  0.09352209,
#          0.90566259, -1.01242284],
#        [ 0.24770824,  0.34844965, -0.22762867, ...,  0.09352209,
#          0.90566259,  0.9877296 ],
#        ...,
#        [-1.95112653,  0.88478069,  0.53269803, ..., -1.06124763,
#         -1.10416397, -1.01242284],
#        [ 0.52256258, -0.25492278,  0.15253468, ...,  0.60162077,
#          0.90566259,  0.9877296 ],
#        [-0.5768548 ,  0.95182207,  2.05335143, ..., -0.85338908,
#         -1.10416397, -1.01242284]])

# %% [markdown]
# ### Box plot to understand the effect of Standard Scaler

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title("Before applying Standard Scalar")
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title("After applying Stanard Scalar")
# Out:
# /tmp/ipykernel_3327/3857156887.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# Text(0.5, 1.0, 'After applying Stanard Scalar')

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

lregressor=LinearRegression()
lregressor.fit(X_train_scaled,y_train)
y_predict=lregressor.predict(X_test)
mae=mean_absolute_error(y_predict,y_test)
score=r2_score(y_predict,y_test)
print(mae)
print(score)
# Out:
# 0.5767877823415978
# 0.9837368587800178

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

Rregressor=Ridge()
Rregressor.fit(X_train_scaled,y_train)
y_predict=Rregressor.predict(X_test)
mae=mean_absolute_error(y_predict,y_test)
score=r2_score(y_predict,y_test)
print(mae)
print(score)
# Out:
# 0.5953582907340912
# 0.9829989266100444

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

Lregressor=Lasso()
Lregressor.fit(X_train_scaled,y_train)
y_predict=Lregressor.predict(X_test)
mae=mean_absolute_error(y_predict,y_test)
score=r2_score(y_predict,y_test)
print(mae)
print(score)
# Out:
# 1.1053469612945104
# 0.9304510200920583

# %% [markdown]
# ### Elastic Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

Eregressor=ElasticNet()
Eregressor.fit(X_train_scaled,y_train)
y_predict=Eregressor.predict(X_test)
mae=mean_absolute_error(y_predict,y_test)
score=r2_score(y_predict,y_test)
print(mae)
print(score)
# Out:
# 1.834545337587552
# 0.8020912709874064

# %%
import pickle
pickle.dump(Scaler,open('scaler.pkl','wb'))
pickle.dump(Ridge,open('ridge.pkl','wb'))
