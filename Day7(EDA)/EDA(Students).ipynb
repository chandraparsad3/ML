# %% [markdown]
# ### EDA of Students performance

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### Checking Data to perform EDA
#  #### Check Missing Values
#  #### Check duplicated Values
#  #### Check data type
#  #### Check statistics of dataset
#  #### Check unique value of each
#  #### Check various category present in the dataset

# %% [markdown]
# ### Checking Missing Values

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# #### Checking duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Check Datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ### Checking unique()

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %% [markdown]
# ### checking statistics

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
cat_value=[feature for feature in df.columns if df[feature].dtypes=='O']
num_value=[feature for feature in df.columns if df[feature].dtypes!='O']

# %%
cat_value
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
num_value
# Out:
# ['math score', 'reading score', 'writing score']

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
df['total_marks']=df['math score']+df['reading score']+df['writing score']
df['average']=df['total_marks']/3

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
fig,axis=plt.subplots(1,2,figsize=(10,6))
plt.subplot(121)
sns.histplot(data=df,x='total_marks',kde=True,bins=30,color='g')
plt.subplot(122)
sns.histplot(data=df,x='total_marks',kde=True,bins=30,hue='gender')
# Out:
# <AxesSubplot: xlabel='total_marks', ylabel='Count'>

# %% [markdown]
# ### Female scores more marks than male

# %%
fig,axis=plt.subplots(1,3,figsize=(15,10))
plt.subplot(141)
sns.histplot(data=df,x='average',hue='parental level of education',kde=True)
plt.subplot(142)
sns.histplot(data=df[df['gender']=='female'],x='average',hue='parental level of education',kde=True)
plt.subplot(143)
sns.histplot(data=df[df['gender']=='male'],x='average',hue='parental level of education',kde=True)
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %%
fig,axis=plt.subplots(1,3,figsize=(15,10))
plt.subplot(141)
sns.histplot(data=df,x='average', hue='lunch',kde=True)
plt.subplot(142)
sns.histplot(data=df[df['gender']=='male'],hue='lunch',x='average',kde=True)
plt.subplot(143)
sns.histplot(data=df[df['gender']=='female'],hue='lunch',x='average',kde=True)
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>

# %%
axis,fig=plt.subplots(1,3,figsize=(20,10))
plt.subplot(141)
sns.histplot(data=df,x='total_marks',hue='race/ethnicity',kde=True)
plt.subplot(142)
sns.histplot(data=df[df['gender']=='male'],x='total_marks',hue='race/ethnicity',kde=True)
plt.subplot(143)
sns.histplot(data=df[df['gender']=='female'],x='total_marks',hue='race/ethnicity',kde=True)
# Out:
# <AxesSubplot: xlabel='total_marks', ylabel='Count'>

# %%
axis,fig=plt.subplots(1,3,figsize=(20,10))
plt.subplot(141)
sns.histplot(data=df,x='average',hue='race/ethnicity',kde=True)
plt.subplot(142)
sns.histplot(data=df[df['gender']=='male'],x='average',hue='race/ethnicity',kde=True)
plt.subplot(143)
sns.histplot(data=df[df['gender']=='female'],x='average',hue='race/ethnicity',kde=True)
# Out:
# <AxesSubplot: xlabel='average', ylabel='Count'>
